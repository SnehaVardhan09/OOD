# %% [markdown]
# ### Class Relationships
# * lot of **Classes** and they might have relationships
# * Aggregation (has a relation. e.g *Customer* has a *Address*)
# * Inheritance

# %% [markdown]
# ### Aggergation
# * **Address** class is given has a input to **customer** class
# * Cannot fetch private attributes

# %%
class Customer:

    def __init__(self, name, age, address):
        self.name = name
        self.age = age
        self.address =address

    def print_address(self):
        print(self.address.locality, self.address.city, self.address.district)

class Address:

    def __init__(self, locality, city, district):
        self.locality = locality
        self.city = city
        self.district = district

add1 = Address('srinivasa', 'newyork', 'elizibeth_nagar')
cust1 = Customer('snehakanth', '27', add1)

cust1.print_address()
# Out:
# srinivasa newyork elizibeth_nagar

# %%
## method 

class Customer:

    def __init__(self, name, age, address):
        self.name = name
        self.age = age
        self.address =address

    def print_address(self):
        print(self.address.locality, self.address.city, self.address.district)

    def EditProfile(self, new_name, new_locality, new_city, new_district):
        self.name = new_name
        self.address.EditAddress(new_locality, new_city, new_district)

class Address:

    def __init__(self, locality, city, district):
        self.locality = locality
        self.city = city
        self.district = district

    def EditAddress(self, new_locality, new_city, new_district):
        self.city = new_city
        self.locality = new_locality
        self.district = new_district


add1 = Address('srinivasa', 'newyork', 'elizibeth_nagar')
cust1 = Customer('snehakanth', '27', add1)

cust1.print_address()

cust1.EditProfile('vardhan', 'loc1', 'city1', 'dist1')
cust1.print_address()
# Out:
# srinivasa newyork elizibeth_nagar
# loc1 city1 dist1

# %% [markdown]
# ![image.png](attachment:image.png) <br>
# *  ** represents aggregation

# %% [markdown]
# ### Inheritance
# ![](attachment:image.png) <br>
# ![image-2.png](attachment:image-2.png)

# %%
#parent
class User:

    def __init__(self):
        self.name = 'sneha'
    
    def login(self):
        print('login')

#child
class Student(User):

    def __init__(self):
        self.rollno = 9

    def enroll(self):
        print('enroll into the course')


u = User()
s = Student()

print(s.name)
print(s.rollno)
s.login()
s.enroll()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 23
#      20 u = User()
#      21 s = Student()
# ---> 23 print(s.name)
#      24 print(s.rollno)
#      25 s.login()
#
# AttributeError: 'Student' object has no attribute 'name'

# %% [markdown]
# * Since the Student class already has a constructor its not inheriting the attributes from parent class(User)
# * If we remove constructor from the student class the code works

# %% [markdown]
# What gets inherited?
# * Constructor
# * Non private Attributes / methods

# %%
# Constructor Example

class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print('buying a phone')

class SmartPhone(Phone):
    pass

s1 = SmartPhone(20000, 'honor', 500)
s1.buy()
# Out:
# Inside phone constructor
# buying a phone

# %%
# Constructor Example2 

class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print('buying a phone')

class SmartPhone(Phone):

    def __init__(self, os, ram):
        self.os = os 
        self.ram = ram
        print('inside SmartPhone constructor')

s2 = SmartPhone('linux', 500)
s2.brand
# Out:
# inside SmartPhone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 21
#      18         print('inside SmartPhone constructor')
#      20 s2 = SmartPhone('linux', 500)
# ---> 21 s2.brand
#
# AttributeError: 'SmartPhone' object has no attribute 'brand'

# %% [markdown]
# * *brand* attribute is not executed yet, *Phone* class is not executed

# %%
# Child cant access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
    
    def show(self):
        print(self.__price)

class SmartPhone(Phone):

    def check(self):
        print(self.__price)

s2 = SmartPhone(10000, 'linux', 500)
print(s2.brand)
s2.check()
# Out:
# Inside phone constructor
# linux
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 20
#      18 s2 = SmartPhone(10000, 'linux', 500)
#      19 print(s2.brand)
# ---> 20 s2.check()
#
# Cell In[15], line 16, in SmartPhone.check(self)
#      15 def check(self):
# ---> 16     print(self.__price)
#
# AttributeError: 'SmartPhone' object has no attribute '_SmartPhone__price'

# %%
# accessing parent private attribute with getter method

class Parent:

    def __init__(self, num):
        self.__num = num
    
    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print(" this is in child class")

son = Child(100)
print(son.get_num())
son.show()
# Out:
# 100
#  this is in child class

# %%
# If child has constructor, parent constructor not called

class Parent:

    def __init__(self, num):
        self.__num = num
    
    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self, val, num):
        self.__val = val 

    def get_val(self):
        return self.__val 

son = Child(100, 10)
print(son.get_num())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 20
#      17         return self.__val
#      19 son = Child(100, 10)
# ---> 20 print(son.get_num())
#      21 son.show()
#
# Cell In[17], line 9, in Parent.get_num(self)
#       8 def get_num(self):
# ----> 9     return self.__num
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
class A:
    def __init__(self):
        self.var1 = 100

    def display1(self, var1):
        print("class A:", self.var1)

class B(A):
    
    def display2(self, var1):
        print('class B:', self.var1)

obj = B()
obj.display1(200)
# Out:
# class A: 100

# %% [markdown]
# ### Method Overriding

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print("buying a smartphone")

p1 = SmartPhone(10000, 'apple', '12mp')
p1.buy()
# Out:
# inside phone constructor
# buying a smartphone

# %% [markdown]
# ### Super Keyword

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print("buying a smartphone")
        #syntax to call parents buy method
        super().buy()

p1 = SmartPhone(10000, 'apple', '12mp')
p1.buy()
# Out:
# inside phone constructor
# buying a smartphone
# buying a phone

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand , camera, os, ram):
        print('inside smartphone constructor')
        super().__init__(price, brand, camera)
        self.os = os
        self.ram = ram
        print('inside smartphone constructor')

s = SmartPhone(20000, "samsung", 12, "android", 2)
print(s.os)
print(s.brand)
# Out:
# inside smartphone constructor
# inside phone constructor
# inside smartphone constructor
# android
# samsung

# %% [markdown]
# * super() is an inbuilt function which is used to invoke the parent class methods and cosntructor
# * **super** keyword cannot be called outside

# %% [markdown]
# * Inheritance improves code reuse
# * Parent has no access to the child class

# %%
#ex 

class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):
  
    def __init__(self,num,val):
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val
      
son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200
        
    def show(self):
        print(self.num)  ### son is self that can call "num"
        print(self.var)

son=Child()
son.show()
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %% [markdown]
# ### Type of inheritance
# * Single
# * Multilevel
# * Hierarchical
# * Multiple
# * Hybrid

# %%
# single

# single inheritance
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# multilevel
class Product:
    def review(self):
        print ("Product customer review")

class Phone(Product):
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Product customer review

# %%
# Hierarchical
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

class FeaturePhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
FeaturePhone(10,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
# Multiple  # Not applicable in Java
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def review(self):
        print ("Customer review")

class SmartPhone(Phone, Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Customer review

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Phone,Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):
  
    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2()) # 20 30 20
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):
  
    def m1(self):
        val=self.m1()+20
        return val
obj=C()
print(obj.m1())
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Polymorphism
# * Method Overriding
# * Method Overloading (Two method with same name in the class)
# * Operator Overloading

# %%
class shape:

    def area(self, radius):  #same name 1 input
        return 3.14* radius*radius

    def area(self, l, b):    #same name 2 input
        return l*B

s= shape()
s.area(3)
s.area(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       7         return l*B
#       9 s= shape()
# ---> 10 s.area(3)
#      11 s.area(3,4)
#
# TypeError: area() missing 1 required positional argument: 'b'

# %%
class shape:

    def area(self, a, b = 0):
        if b == 0:
            return 3.14* a*a
        else:
            return a*b
    
s= shape()
s.area(3)
s.area(3,4)
# Out:
# 12
